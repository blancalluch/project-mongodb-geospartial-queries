# %%
import pandas as pd
import re
import getpass
import json
import numpy as np
import json
import functions as f

# %%
airports=pd.read_csv("./output/airports.csv")

# %%
with open('./output/1M_company_officess.json', 'r') as myfile:
    data=myfile.read()

# %%
obj = json.loads(data)

# %%
x=pd.DataFrame(obj)
x.head()
# Out:
#                         ref     Name Category  \
# 0  52cdef7c4bab8bd675297d8d     Digg     news
# 1  52cdef7c4bab8bd675297d91     Geni      web
# 2  52cdef7c4bab8bd675297d96   Gizmoz      web
# 3  52cdef7c4bab8bd675297d97   Scribd     news
# 4  52cdef7c4bab8bd675297d98  Slacker    music
#
#                           Description   Latitude   Longitude  Founded Year  \
# 0  user driven social content website  37.764726 -122.394523        2004.0
# 1       Geneology social network site  34.090368 -118.393064        2006.0
# 2                     Photo animation  37.484130 -122.169472        2003.0
# 3                Read Unlimited Books  37.789634 -122.404052        2007.0
# 4         Music Personalization Suite  33.022176 -117.081406        2006.0
#
#   Total Money Raised  Raised Amount Currency                          Address  \
# 0               $45M     45000000.0      USD               135 Mississippi St
# ...

# %%
cities=(set(x['City']))

# %%
a=set(airports['Papua New Guinea'])

# %%
count=0
for city in cities:
    if city in a:
        count+=1
        print(city)
# Out:
# Netherlands
# Hong Kong
# Mexico
# Switzerland
# Luxembourg
# Singapore

# %%
a
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'American Samoa',
#  'Angola',
#  'Anguilla',
#  'Antarctica',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'British Indian Ocean Territory',
#  'British Virgin Islands',
#  'Brunei',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burma',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Cape Verde',
#  'Cayman Islands',
#  'Central African Republic',
#  'Chad',
#  'Chile',
#  'China',
#  'Christmas Island',
#  'Cocos (Keeling) Islands',
#  'Colombia',
#  'Comoros',
#  'Congo (Brazzaville)',
#  'Congo (Kinshasa)',
#  'Cook Islands',
#  'Costa Rica',
#  "Cote d'Ivoire",
#  'Croatia',
#  'Cuba',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Djibouti',
# ...
