# %% [markdown]
# ## Airport Filtering

# %%
import connectionMongoDB as mongo
import json
import pandas as pd
import getLocation as gl
from haversine import haversine,Unit

# %% [markdown]
# - All information from airports.csv from: https://ourairports.com/data/

# %%
db_airp, coll_airp = mongo.connectCollection('companies','airport')

# %%
airport_locations = list(coll_airp.find())

# %% [markdown]
# - Adding geolocations to the large airports:

# %%
for a in airport_locations:
    long=a['longitude_deg']
    lat=a['latitude_deg']
    value = {"$set": {'location':gl.getLocation(long,lat)}}
    coll_airp.update_one(a,value)

# %%
len(airport_locations)
# Out:
# 615

# %% [markdown]
# - Exporting json with schools, starbucks and companies with more than 1M$ raised.

# %%
with open('./output/StarbucksSchool_1M.json', 'r') as myfile:
    data=myfile.read()
obj = json.loads(data)
merge3=pd.DataFrame(obj)

# %%
merge3_df=pd.DataFrame(merge3)

# %%
airports_df=pd.DataFrame(airport_locations)

# %%
for ,_row in merge3_df.iterrows():
# Out:
#                           _id      id    ident           type  \
# 0    5dd6b8fbc0882b53f909bbe6      67     AYPY  large_airport
# 1    5dd6b8fbc0882b53f909bdb6     123     BIKF  large_airport
# 2    5dd6b8fbc0882b53f909bde5    4614     BKPR  large_airport
# 3    5dd6b8fbc0882b53f909bde8  332694      BLR  large_airport
# 4    5dd6b8fbc0882b53f909c971  329666  CN-0083  large_airport
# ..                        ...     ...      ...            ...
# 610  5dd6b8fcc0882b53f90a667f   27230     ZUUU  large_airport
# 611  5dd6b8fcc0882b53f90a66c1   27236     ZWWW  large_airport
# 612  5dd6b8fcc0882b53f90a66cd   27238     ZYHB  large_airport
# 613  5dd6b8fcc0882b53f90a66db   27242     ZYTL  large_airport
# 614  5dd6b8fcc0882b53f90a66dd   27243     ZYTX  large_airport
#
#                                                   name  latitude_deg  \
# 0          Port Moresby Jacksons International Airport     -9.443380
# 1                       Keflavik International Airport     63.985001
# 2                       Priština International Airport     42.572800
# 3    Duplicate - Kempegowda International Airport B...      0.100000
# 4                                       Guodu air base     36.001741
# ..                                                 ...           ...
# 610            Chengdu Shuangliu International Airport     30.578501
# 611                Ürümqi Diwopu International Airport     43.907101
# 612                                    Taiping Airport     45.623402
# 613                                 Zhoushuizi Airport     38.965698
# 614                                    Taoxian Airport     41.639801
#
#      longitude_deg elevation_ft continent iso_country iso_region  \
# 0       147.220001          146        OC          PG     PG-NCD
# 1       -22.605600          171        EU          IS       IS-2
# 2        21.035801         1789        EU          XK      XK-01
# 3         0.100000                     AS          IN      IN-KA
# 4       117.632010                     AS          CN     CN-U-A
# ..             ...          ...       ...         ...        ...
# 610     103.946999         1625        AS          CN      CN-51
# 611      87.474197         2125        AS          CN      CN-65
# 612     126.250000          457        AS          CN      CN-23
# 613     121.539001          107        AS          CN      CN-21
# 614     123.483002          198        AS          CN      CN-21
#
#      municipality scheduled_service gps_code iata_code local_code  \
# 0    Port Moresby               yes     AYPY       POM
# 1       Reykjavík               yes     BIKF       KEF
# 2       Prishtina               yes     BKPR       PRN
# 3       Bengaluru               yes     VOBL       BLR
# 4                                no
# ..            ...               ...      ...       ...        ...
# 610       Chengdu               yes     ZUUU       CTU
# 611        Ürümqi               yes     ZWWW       URC
# 612        Harbin               yes     ZYHB       HRB
# 613        Dalian               yes     ZYTL       DLC
# 614      Shenyang               yes     ZYTX       SHE
#
#                                              home_link  \
# 0
# 1
# 2                      http://www.airportpristina.com/
# 3
# 4
# ..                                                 ...
# 610  http://www.cdairport.com/cdairport/en_front/in...
# 611
# 612
# 613
# 614
#
#                                         wikipedia_link  \
# 0    https://en.wikipedia.org/wiki/Jacksons_Interna...
# 1    https://en.wikipedia.org/wiki/Keflav%C3%ADk_In...
# 2    https://en.wikipedia.org/wiki/Pristina_Interna...
# 3
# 4
# ..                                                 ...
# 610  https://en.wikipedia.org/wiki/Chengdu_Shuangli...
# 611  https://en.wikipedia.org/wiki/%C3%9Cr%C3%BCmqi...
# 612  https://en.wikipedia.org/wiki/Harbin_Taiping_I...
# 613  https://en.wikipedia.org/wiki/Dalian_Zhoushuiz...
# 614  https://en.wikipedia.org/wiki/Shenyang_Taoxian...
#
#                              keywords  \
# 0
# 1      Keflavik Naval Air Station,REK
# 2    LYPR, Pristina, Slatina Air Base
# 3
# 4
# ..                                ...
# 610                          成都双流国际机场
# 611
# 612
# 613                   Dalian Air Base
# 614
#
#                                               location
# 0    {'type': 'Point', 'coordinates': [147.22000122...
# 1    {'type': 'Point', 'coordinates': [-22.60560035...
# 2    {'type': 'Point', 'coordinates': [21.035801, 4...
# 3         {'type': 'Point', 'coordinates': [0.1, 0.1]}
# 4    {'type': 'Point', 'coordinates': [117.63201, 3...
# ..                                                 ...
# 610  {'type': 'Point', 'coordinates': [103.94699859...
# 611  {'type': 'Point', 'coordinates': [87.474197387...
# 612  {'type': 'Point', 'coordinates': [126.25, 45.6...
# 613  {'type': 'Point', 'coordinates': [121.53900146...
# 614  {'type': 'Point', 'coordinates': [123.48300170...
#
# [615 rows x 20 columns]
